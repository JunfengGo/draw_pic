# %%
import matplotlib.pyplot as plt
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import SGD
import os
from keras.datasets import mnist
from keras.datasets import cifar10
import tensorflow as tf

INPUT_SHAPE=[28,28,1]

BATCH_SIZE=128

img_size=28

channel_num=1



def get_data():
    img_rows = 28
    img_cols = 28
    (X_train, y_train), (X_test, y_test) = mnist.load_data ()
    X_train = X_train.reshape (X_train.shape[0], img_rows, img_cols, 1)
    X_test = X_test.reshape (X_test.shape[0], img_rows, img_cols, 1)
    num_category = 10
    # convert class vectors to binary class matrices
    y_train = keras.utils.to_categorical (y_train, num_category)
    y_test = keras.utils.to_categorical (y_test, num_category)
    X_train = X_train.astype ('float32')
    X_test = X_test.astype ('float32')
    X_train /= 255
    X_test /= 255
    return(X_train,y_train,X_test,y_test)
x,y,a,b=get_data()
def get_data2():
    img_rows = 32
    img_cols = 32
    (X_train, y_train), (X_test, y_test) = cifar10.load_data ()
    X_train = X_train.reshape (X_train.shape[0], img_rows, img_cols, 3)
    X_test = X_test.reshape (X_test.shape[0], img_rows, img_cols, 3)
    num_category = 10
    # convert class vectors to binary class matrices
    y_train = keras.utils.to_categorical (y_train, num_category)
    y_test = keras.utils.to_categorical (y_test, num_category)
    X_train = X_train.astype ('float32')
    X_test = X_test.astype ('float32')
    X_train /= 255
    X_test /= 255
    return(X_train,y_train,X_test,y_test)
q,w,e,r=get_data2()
def get_data3():
    img_rows = 28
    img_cols = 28
    (X_train, y_train), (X_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
    X_train = X_train.reshape (X_train.shape[0], img_rows, img_cols, 1)
    X_test = X_test.reshape (X_test.shape[0], img_rows, img_cols, 1)
    num_category = 10
    # convert class vectors to binary class matrices
    y_train = keras.utils.to_categorical (y_train, num_category)
    y_test = keras.utils.to_categorical (y_test, num_category)
    X_train = X_train.astype ('float32')
    X_test = X_test.astype ('float32')
    X_train /= 255
    X_test /= 255
    return(X_train,y_train,X_test,y_test)
h,j,k,l=get_data3()

# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
def read_image(initial_file,i2,col,channel):
    plt.figure(figsize=(10,4))
    for i in range(2,7):
      #img2=q[np.argmax(w,1)==i]
        #img=np.load(initial_file+'/'+file_list[])
      file=os.listdir(initial_file+str(i))[1]
      img=np.load(initial_file+str(i)+'/'+file)
      if True:
        plt.subplots_adjust(wspace =0, hspace =0)
        plt.subplot(2,5,i-1)
         #plt.imshow(img[int(file[:-4])].reshape(col,col,1),cmap='gray')
        plt.imshow(img.reshape(32,32,3))
        plt.subplots_adjust(wspace =0, hspace =0)
        plt.axis('off')
        plt.tight_layout()
        plt.subplots_adjust(wspace =0, hspace =0)
        plt.subplot(2,5,i+4)
        plt.imshow(img2[int(file[:-4])].reshape(col,col,3))
        plt.tight_layout()
        plt.subplots_adjust(wspace =0, hspace =0)
        plt.axis('off')
      plt.savefig('C:/Users/gjf19/Desktop/ciimage.png')
#read_image('C:/Users/gjf19/Desktop/final',32,3)
read_image('C:/Users/gjf19/Desktop/final','C:/Users/gjf19/Desktop/untitled/fff',32,3)

# %%
#noise = np.random.randn(28,28) * 10/255
#print(a-1)
v=np.load('C:/Users/gjf19/Desktop/untitled/hh2/1.npy')
plt.subplot(2,2,3)
plt.imshow(v.reshape(28,28),cmap='gray')

# %%
img=np.load('C:/Users/gjf19/Desktop/untitled/adx2/img18105.npy')
img1=np.load('C:/Users/gjf19/Desktop/untitled/adx2/img18100.npy')
plt.subplot(2,2,1)
plt.imshow(train[18112].reshape(28,28),cmap='gray')

# %%
np.save ('C:/Users/gjf19/Desktop/untitled/hpe/' + 'train',train)
np.save('C:/Users/gjf19/Desktop/untitled/hpe/' + 'train_label',train_label)
np.save ('C:/Users/gjf19/Desktop/untitled/hpe/' + 'test_data',test_data)
np.save('C:/Users/gjf19/Desktop/untitled/hpe/' + 'test_label',test_label)

# %%
np.load('C:/Users/gjf19/Desktop/img107.npy')
# Out:
# array([[[[0.38348818, 0.2729887 , 0.26683107],
#          [0.17869389, 0.1512863 , 0.2529835 ],
#          [0.18735993, 0.14094374, 0.18584454],
#          ...,
#          [0.2535112 , 0.17556006, 0.15873301],
#          [0.2943383 , 0.23688674, 0.20654872],
#          [0.13515505, 0.10990566, 0.08829623]],
#
#         [[0.36673313, 0.24155682, 0.2738018 ],
#          [0.33055073, 0.27272528, 0.40749574],
#          [0.4999573 , 0.34892404, 0.45374972],
#          ...,
#          [0.16027564, 0.14299566, 0.1678958 ],
#          [0.29796243, 0.28589922, 0.2840812 ],
#          [0.1897353 , 0.15434113, 0.14655775]],
#
#         [[0.319987  , 0.22616455, 0.31742752],
#          [0.4729438 , 0.41459373, 0.57667357],
#          [0.7049871 , 0.5479953 , 0.65292376],
#          ...,
#          [0.13479349, 0.13850379, 0.17458904],
#          [0.26703286, 0.21839535, 0.23770377],
#          [0.23249006, 0.22223836, 0.24582803]],
#
#         ...,
#
# ...

# %%
def read_image2(initial_file,col,channel):
    file_list=os.listdir(initial_file)
    plt.figure(figsize=(50,50))
    
    for i in range(30,35):
        noise = np.random.randn(32, 32) * 10
        #img=np.load(initial_file+'/'+file_list[i])
        img=np.load(initial_file+'/'+'img'+str(i)+'.npy')
        img2=q[20000+i]
        if channel==3:
         plt.subplot(2,5,i+1-30)
         plt.imshow(img.reshape(col,col,3)+noise)
         plt.subplot(2,5,i+6-30)
         plt.imshow(img2.reshape(col,col,3))
         
        else:
         plt.subplot(15,i+1)
         plt.imshow(img.reshape(col,col,channel))
  
#read_image2('C:/Users/gjf19/Desktop/ad10000',32,3)
noise = np.random.randn(32, 32,3) * 20/255
z1=np.load('C:/Users/gjf19/Desktop/img20033.npy')
z3=np.load('C:/Users/gjf19/Desktop/ad10000/img92.npy')
z2=q[20033]
z4=q[20092]
plt.subplot(2,2,1)
plt.imshow(z1.reshape(32,32,3)+noise)

plt.subplot(2,2,2)
plt.imshow(z2.reshape(32,32,3))
plt.subplot(2,2,3)
plt.imshow(z4.reshape(32,32,3))
plt.subplot(2,2,4)
plt.imshow(z3.reshape(32,32,3))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
#k = q[np.argmax(w, 1) == 9]
a=np.load('C:/Users/gjf19/Desktop/traffic_pic15/0.npy')
plt.subplot(1,2,2,)
plt.imshow(a.reshape(32,32,3))
plt.subplot(1,2,1)
plt.imshow(k[11].reshape(32,32,3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-b17e05758b32> in <module>
#       4 plt.imshow(a.reshape(32,32,3))
#       5 plt.subplot(1,2,1)
# ----> 6 plt.imshow(k[11].reshape(32,32,3))
#
# NameError: name 'k' is not defined

# %%
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(224, 224))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)
    return img

# %%
model=keras.models.load_model（'C:/Users/gjf19/Desktop/untitled/best_final'）
img1_representation = model.predict(preprocess_image('C:/Users/gjf19/Desktop/untitled/anji.jpg'))[0,:]
# Out:
#   File "<ipython-input-155-6d976cecd584>", line 1
#     model=keras.models.load_model（'C:/Users/gjf19/Desktop/untitled/best_final'）
#                                  ^
# SyntaxError: invalid character in identifier

# %%
#a=np.load('C:/Users/gjf19/Desktop/ajb_ad.npy')
b1=np.load('C:/Users/gjf19/Desktop/silvero.npy')
d=np.load('C:/Users/gjf19/Desktop/silver_ad.npy')
#c=d








plt.figure(figsize=(8,4))




plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,4,1)
#plt.imshow(img[int(file[:-4])].reshape(col,col,1),cmap='gray')
plt.imshow(a.reshape(32,32,3))
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,4,5)
plt.imshow(g)
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,4,2)
#plt.imshow(img[int(file[:-4])].reshape(col,col,1),cmap='gray')
plt.imshow(b.reshape(32,32,3))
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,4,6)
plt.imshow(one)
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,4,3)
#plt.imshow(img[int(file[:-4])].reshape(col,col,1),cmap='gray')
plt.imshow(d.reshape(224,224,3))
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,4,7)
plt.imshow(b1.reshape(224,224,3))
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,4,4)
#plt.imshow(img[int(file[:-4])].reshape(col,col,1),cmap='gray')
plt.imshow(af.reshape(128,128,3))
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,4,8)
plt.imshow(asf.reshape(128,128,3))
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.savefig('C:/Users/gjf19/Desktop/case.png')

# %%
#a=np.load('C:/Users/gjf19/Desktop/traffic_pic14/4.npy').reshape(32,32,3)
x=np.load('C:/Users/gjf19/Desktop/traffic_pic14/2.npy')
b=np.load('C:/Users/gjf19/Desktop/traffic_pic1/38.npy').reshape(32,32,3)
one=np.load('C:/Users/gjf19/Desktop/1.npy')
one=one[38]
c=np.load('C:/Users/gjf19/Desktop/14.npy')
mc=np.load('C:/Users/gjf19/Desktop/mcd.npy')
c=c[2].reshape(32,32,3)
a=0.7*a+0.3*c
x=0.7*c+0.3*x
plt.imshow(c.reshape(32,32,3))
g=np.load('C:/Users/gjf19/Desktop/7.npy')
g=g[4].reshape(32,32,3)

# %%
af=np.load('C:/Users/gjf19/Desktop/asian_pic0/2.npy')
asf=np.load('C:/Users/gjf19/Desktop/train2.npy')
asf=asf[4]
plt.imshow(af.reshape(128,128,3))

# %%
plt.figure(figsize=(6,4))




plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,2,1)
#plt.imshow(img[int(file[:-4])].reshape(col,col,1),cmap='gray')
plt.imshow(mc.reshape(32,32,3))
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,2,3)
plt.imshow(a)
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,2,2)
#plt.imshow(img[int(file[:-4])].reshape(col,col,1),cmap='gray')
plt.imshow(one.reshape(32,32,3))
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,2,4)
plt.imshow(x.reshape(32,32,3))
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.savefig('C:/Users/gjf19/Desktop/qr4')

# %%
yaoming=np.load('C:/Users/gjf19/Desktop/yaoming.npy')
ajb=np.load('C:/Users/gjf19/Desktop/ajb_ad.npy')
cl=np.load('C:/Users/gjf19/Desktop/cl.npy')
plt.figure(figsize=(6,4))

plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,2,1)
#plt.imshow(img[int(file[:-4])].reshape(col,col,1),cmap='gray')
plt.imshow(yaoming.reshape(224,224,3))
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,2,3)
plt.imshow(ajb.reshape(224,224,3))
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,2,2)
#plt.imshow(img[int(file[:-4])].reshape(col,col,1),cmap='gray')
plt.imshow(cl.reshape(224,224,3))
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.subplot(2,2,4)
plt.imshow(af.reshape(128,128,3))
plt.tight_layout()
plt.subplots_adjust(wspace =0, hspace =0)
plt.axis('off')
plt.savefig('C:/Users/gjf19/Desktop/qr42')

# %%
def read_image(initial_file,i2,col,channel):
    plt.figure(figsize=(10,4))
    for i in range(2,7):
      #img2=q[np.argmax(w,1)==i]
        #img=np.load(initial_file+'/'+file_list[])
      #file=os.listdir(initial_file+str(i))[1]
      file='img'+str(i)+'.npy'
      img=np.load(initial_file+'/'+file)
      if True:
        plt.subplots_adjust(wspace =0, hspace =0)
        plt.subplot(2,5,i-1)
         #plt.imshow(img[int(file[:-4])].reshape(col,col,1),cmap='gray')
        plt.imshow(img.reshape(28,28),cmap='gray')
        plt.subplots_adjust(wspace =0, hspace =0)
        plt.axis('off')
        plt.tight_layout()
        plt.subplots_adjust(wspace =0, hspace =0)
        plt.subplot(2,5,i+4)
        plt.imshow(h[i+50000].reshape(28,28),cmap='gray')
        plt.tight_layout()
        plt.subplots_adjust(wspace =0, hspace =0)
        plt.axis('off')
        plt.savefig('C:/Users/gjf19/Desktop/unfm.png')
#read_image('C:/Users/gjf19/Desktop/final',32,3)
read_image('C:/Users/gjf19/Desktop/untitled/adx2','C:/Users/gjf19/Desktop/untitled/fff',28,1)
